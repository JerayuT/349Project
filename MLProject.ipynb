# %%
import pandas as pd

# %%
train_review = pd.read_json('Toys_and_Games/train/review_training.json')
train_product = pd.read_json('Toys_and_Games/train/product_training.json')

# %%
train = train_review.merge(train_product, left_on = 'asin', right_on = 'asin')

# %%
train[train['style'].notnull()]
# Out:
#                                     asin                        reviewerID  \
# 41      EBBA37B59AD406B995BF4A81737111CE  EF6AC2A187C9FAD4CDA4BD9C3632DE33
# 42      EBBA37B59AD406B995BF4A81737111CE  271788D1510E20AB57198AD6E4CA418E
# 43      EBBA37B59AD406B995BF4A81737111CE  42F1223F2D2FF302F74789C480175D22
# 44      EBBA37B59AD406B995BF4A81737111CE  8E057A8D4845FF5277E90345A754BF2C
# 45      EBBA37B59AD406B995BF4A81737111CE  568BEBB56DC9FD4E5827C95A5F0A6D7F
# ...                                  ...                               ...
# 988354  45FBF2C4CA0C34689056178C7EB23530  FF2447A01A14B24B2A913DDC4A418257
# 988358  B219856E8E1D5DEE57D2D047165BC160  859AF8F730284BA7C89885A35DDF42B7
# 988371  0878A0654F3D53ED5D6B45B9A5152D2D  98152485240FAB6A1C70FA97BB9D9858
# 988397  EAFEF0761CE618F5B2F8EB88A5104466  9FFF172AC520A5E1969D225F13F03291
# 988405  DE6F9BA2BF26934A1BADCB12925B108A  15A9F4CE33ACC931FCB17FE98AAC05F0
#
#         unixReviewTime  verified   reviewTime  \
# ...

# %%
train.shape
# Out:
# (988406, 12)
